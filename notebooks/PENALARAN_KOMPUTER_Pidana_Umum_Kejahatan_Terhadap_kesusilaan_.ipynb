# %% [markdown]
# # **Tahap 1 – Membangun Case Base**

# %% [markdown]
# ### Seleksi & Unduh

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas requests beautifulsoup4 pdfminer.six lxml > /dev/null 2>&1

# %%
import argparse
import io
import os
import re
import time
import urllib
from concurrent.futures import ThreadPoolExecutor, wait
from datetime import date
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pdfminer.high_level import extract_text

# %%
def create_path(folder_name):
    path = os.path.join(os.getcwd(), folder_name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

def open_page(link):
    count = 0
    while count < 3:
        try:
            return BeautifulSoup(requests.get(link).text, "lxml")
        except:
            count += 1
            time.sleep(5)


def get_detail(soup, keyword):
    try:
        text = (
            soup.find(lambda tag: tag.name == "td" and keyword in tag.text)
            .find_next()
            .get_text()
            .strip()
        )
        return text
    except:
        return ""


def get_pdf(url, path_pdf):
    try:
        file = urllib.request.urlopen(url)
        file_name = os.path.basename(url)
        file_content = file.read()
        with open(f"{path_pdf}/{file_name}", "wb") as out_file:
            out_file.write(file_content)
        return io.BytesIO(file_content), file_name
    except:
        return None, None


def clean_text(text):
    text = text.replace("M a h ka m a h A g u n g R e p u blik In d o n esia\n", "")
    text = text.replace("Disclaimer\n", "")
    text = text.replace(
        "Kepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\n",
        "",
    )
    text = text.replace(
        "pelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\n",
        "",
    )
    text = text.replace(
        "Dalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\n",
        "",
    )
    text = text.replace(
        "Email : kepaniteraan@mahkamahagung.go.id    Telp : 021-384 3348 (ext.318)\n",
        "",
    )
    return text


def extract_data(link, keyword_url, path_output, path_pdf, today):
    soup = open_page(link)
    table = soup.find("table", {"class": "table"})
    judul = table.find("h2").text if table.find("h2") else ""

    nomor = get_detail(table, "Nomor")
    tingkat_proses = get_detail(table, "Tingkat Proses")
    klasifikasi = get_detail(table, "Klasifikasi")
    kata_kunci = get_detail(table, "Kata Kunci")
    tahun = get_detail(table, "Tahun")
    tanggal_register = get_detail(table, "Tanggal Register")
    lembaga_peradilan = get_detail(table, "Lembaga Peradilan")
    jenis_lembaga_peradilan = get_detail(table, "Jenis Lembaga Peradilan")
    hakim_ketua = get_detail(table, "Hakim Ketua")
    hakim_anggota = get_detail(table, "Hakim Anggota")
    panitera = get_detail(table, "Panitera")
    amar = get_detail(table, "Amar")
    amar_lainnya = get_detail(table, "Amar Lainnya")
    catatan_amar = get_detail(table, "Catatan Amar")
    tanggal_musyawarah = get_detail(table, "Tanggal Musyawarah")
    tanggal_dibacakan = get_detail(table, "Tanggal Dibacakan")
    kaidah = get_detail(table, "Kaidah")
    status = get_detail(table, "Status")
    abstrak = get_detail(table, "Abstrak")

    try:
        link_pdf = soup.find("a", href=re.compile(r"/pdf/"))["href"]
        file_pdf, file_name_pdf = get_pdf(link_pdf, path_pdf)
        text_pdf = extract_text(file_pdf)
        text_pdf = clean_text(text_pdf)
    except:
        link_pdf = ""
        text_pdf = ""
        file_name_pdf = ""

    data = [
        judul,
        nomor,
        tingkat_proses,
        klasifikasi,
        kata_kunci,
        tahun,
        tanggal_register,
        lembaga_peradilan,
        jenis_lembaga_peradilan,
        hakim_ketua,
        hakim_anggota,
        panitera,
        amar,
        amar_lainnya,
        catatan_amar,
        tanggal_musyawarah,
        tanggal_dibacakan,
        kaidah,
        status,
        abstrak,
        link,
        link_pdf,
        file_name_pdf,
        text_pdf,
    ]
    result = pd.DataFrame(
        [data],
        columns=[
            "judul",
            "nomor",
            "tingkat_proses",
            "klasifikasi",
            "kata_kunci",
            "tahun",
            "tanggal_register",
            "lembaga_peradilan",
            "jenis_lembaga_peradilan",
            "hakim_ketua",
            "hakim_anggota",
            "panitera",
            "amar",
            "amar_lainnya",
            "catatan_amar",
            "tanggal_musyawarah",
            "tanggal_dibacakan",
            "kaidah",
            "status",
            "abstrak",
            "link",
            "link_pdf",
            "file_name_pdf",
            "text_pdf",
        ],
    )

    keyword_url = keyword_url.replace("/", " ")
    if keyword_url.startswith("https"):
        keyword_url = ""
    destination = f"{path_output}/putusan_ma_{keyword_url}_{today}"
    if not os.path.isfile(f"{destination}.csv"):
        result.to_csv(f"{destination}.csv", header=True, index=False)
    else:
        result.to_csv(f"{destination}.csv", mode="a", header=False, index=False)


def run_process(keyword_url, page, sort_date, path_output, path_pdf, today):
    if keyword_url.startswith("https"):
        link = f"{keyword_url}&page={page}"
    else:
        link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword_url}&page={page}"
    if sort_date:
        link = f"{link}&obf=TANGGAL_PUTUS&obm=desc"

    soup = open_page(link)
    links = soup.find_all("a", {"href": re.compile("/direktori/putusan")})

    for link in links:
        extract_data(link["href"], keyword_url, path_output, path_pdf, today)


def run_scraper(keyword=None, url=None, sort_date=True, download_pdf=True):
    if not keyword and not url:
        print("Please provide a keyword or URL")
        return

    path_output = '/content/drive/MyDrive/Penalaran Komputer1/CSV'
    path_pdf = '/content/drive/MyDrive/Penalaran Komputer1/PDF'
    today = date.today().strftime("%Y-%m-%d")

    link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword}&page=1"
    if url:
        link = url

    soup = open_page(link)
    last_page = int(soup.find_all("a", {"class": "page-link"})[-1].get("data-ci-pagination-page"))

    if url:
        print(f"Scraping with url: {url} - {20 * last_page} data - {last_page} page")
    else:
        print(f"Scraping with keyword: {keyword} - {20 * last_page} data - {last_page} page")

    if url:
        keyword_url = url
    else:
        keyword_url = keyword

    futures = []
    with ThreadPoolExecutor(max_workers=4) as executor:
        for page in range(last_page):
            futures.append(
                executor.submit(run_process, keyword_url, page + 1, sort_date, path_output, path_pdf, today)
            )
    wait(futures)

# %%
# Download Pidana Klasifikasi Pidana Umum-Kejahatan Terhadap kesusilaan
run_scraper(url="https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=75d2c54ea4cb6d96d9314955bb46ba07&jd=&tp=0&court=099731PN161+++++++++++++++++++++&t_put=&t_reg=&t_upl=&t_pr=")
# Out:
# Scraping with url: https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=75d2c54ea4cb6d96d9314955bb46ba07&jd=&tp=0&court=099731PN161+++++++++++++++++++++&t_put=&t_reg=&t_upl=&t_pr= - 40 data - 2 page

# %% [markdown]
# ### Konversi & Ekstraksi Teks

# %%
# !pip install pdfminer.six
# Out:
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.11/dist-packages (20250506)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)

# %%
import os

pdf_folder = '/content/drive/MyDrive/Penalaran Komputer1/PDF'
output_folder = '/content/drive/MyDrive/Penalaran Komputer1/data/raw'

os.makedirs(output_folder, exist_ok=True)

# %%
from pdfminer.high_level import extract_text

def convert_pdf_to_txt(pdf_path, txt_path):
    try:
        text = extract_text(pdf_path)
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f'✅ Berhasil konversi: {txt_path}')
    except Exception as e:
        print(f'❌ Gagal konversi {pdf_path}: {e}')

# %%
for i, filename in enumerate(sorted(os.listdir(pdf_folder))):
    if filename.endswith('.pdf'):
        pdf_path = os.path.join(pdf_folder, filename)
        txt_filename = f'case_{i+1:03}.txt'
        txt_path = os.path.join(output_folder, txt_filename)
        convert_pdf_to_txt(pdf_path, txt_path)
# Out:
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_001.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_002.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_003.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_004.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_005.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_006.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_007.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_008.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_009.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_010.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_011.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_012.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_013.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_014.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_015.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_016.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_017.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_018.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_019.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_020.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_021.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_022.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_023.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_024.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_025.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_026.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_027.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_028.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_029.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_030.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_031.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_032.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_033.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_034.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_035.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_036.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_037.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_038.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_039.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_040.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_041.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_042.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_043.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_044.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_045.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_046.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_047.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_048.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_049.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_050.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_051.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_052.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_053.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_054.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_055.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_056.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_057.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_058.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_059.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_060.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_061.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_062.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_063.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_064.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_065.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_066.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_067.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_068.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_069.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_070.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_071.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_072.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_073.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_074.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_075.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_076.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_077.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_078.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_079.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Penalaran Komputer1/data/raw/case_080.txt

# %% [markdown]
# ### Pembersihan

# %%
import os
import re

# Fungsi pembersih
def bersihkan_teks(teks):
    teks = re.sub(r'putusan\.?mahkamahagung\.?go\.?id', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'disclaimer.*?kami sajikan.*?(?=\s|$)', '', teks, flags=re.IGNORECASE | re.DOTALL)
    teks = re.sub(r'kepaniteraan@mahkamahagung\.?go\.?id', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'telp.*?\d{3}.*?(?=\s|$)', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\bhalaman\s*\d+\b', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\bhalaman\b', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\d+\s*dari\s*\d+\s*halaman', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\s+', ' ', teks)
    teks = teks.lower().strip()
    return teks

# Folder input & output
input_folder = '/content/drive/MyDrive/Penalaran Komputer1/data/raw'
output_folder = '/content/drive/MyDrive/Penalaran Komputer1/data_clean/raw'
os.makedirs(output_folder, exist_ok=True)

# Loop semua file .txt
for filename in sorted(os.listdir(input_folder)):
    if filename.endswith('.txt'):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with open(input_path, 'r', encoding='utf-8') as f:
            teks = f.read()

        teks_bersih = bersihkan_teks(teks)

        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(teks_bersih)

        print(f"✅ Dibersihkan dan disimpan: {filename}")
# Out:
# ✅ Dibersihkan dan disimpan: case_001.txt
# ✅ Dibersihkan dan disimpan: case_002.txt
# ✅ Dibersihkan dan disimpan: case_003.txt
# ✅ Dibersihkan dan disimpan: case_004.txt
# ✅ Dibersihkan dan disimpan: case_005.txt
# ✅ Dibersihkan dan disimpan: case_006.txt
# ✅ Dibersihkan dan disimpan: case_007.txt
# ✅ Dibersihkan dan disimpan: case_008.txt
# ✅ Dibersihkan dan disimpan: case_009.txt
# ✅ Dibersihkan dan disimpan: case_010.txt
# ✅ Dibersihkan dan disimpan: case_011.txt
# ✅ Dibersihkan dan disimpan: case_012.txt
# ✅ Dibersihkan dan disimpan: case_013.txt
# ✅ Dibersihkan dan disimpan: case_014.txt
# ✅ Dibersihkan dan disimpan: case_015.txt
# ✅ Dibersihkan dan disimpan: case_016.txt
# ✅ Dibersihkan dan disimpan: case_017.txt
# ✅ Dibersihkan dan disimpan: case_018.txt
# ✅ Dibersihkan dan disimpan: case_019.txt
# ✅ Dibersihkan dan disimpan: case_020.txt
# ✅ Dibersihkan dan disimpan: case_021.txt
# ✅ Dibersihkan dan disimpan: case_022.txt
# ✅ Dibersihkan dan disimpan: case_023.txt
# ✅ Dibersihkan dan disimpan: case_024.txt
# ✅ Dibersihkan dan disimpan: case_025.txt
# ✅ Dibersihkan dan disimpan: case_026.txt
# ✅ Dibersihkan dan disimpan: case_027.txt
# ✅ Dibersihkan dan disimpan: case_028.txt
# ✅ Dibersihkan dan disimpan: case_029.txt
# ✅ Dibersihkan dan disimpan: case_030.txt
# ✅ Dibersihkan dan disimpan: case_031.txt
# ✅ Dibersihkan dan disimpan: case_032.txt
# ✅ Dibersihkan dan disimpan: case_033.txt
# ✅ Dibersihkan dan disimpan: case_034.txt
# ✅ Dibersihkan dan disimpan: case_035.txt
# ✅ Dibersihkan dan disimpan: case_036.txt
# ✅ Dibersihkan dan disimpan: case_037.txt
# ✅ Dibersihkan dan disimpan: case_038.txt
# ✅ Dibersihkan dan disimpan: case_039.txt
# ✅ Dibersihkan dan disimpan: case_040.txt
# ✅ Dibersihkan dan disimpan: case_041.txt
# ✅ Dibersihkan dan disimpan: case_042.txt
# ✅ Dibersihkan dan disimpan: case_043.txt
# ✅ Dibersihkan dan disimpan: case_044.txt
# ✅ Dibersihkan dan disimpan: case_045.txt
# ✅ Dibersihkan dan disimpan: case_046.txt
# ✅ Dibersihkan dan disimpan: case_047.txt
# ✅ Dibersihkan dan disimpan: case_048.txt
# ✅ Dibersihkan dan disimpan: case_049.txt
# ✅ Dibersihkan dan disimpan: case_050.txt
# ✅ Dibersihkan dan disimpan: case_051.txt
# ✅ Dibersihkan dan disimpan: case_052.txt
# ✅ Dibersihkan dan disimpan: case_053.txt
# ✅ Dibersihkan dan disimpan: case_054.txt
# ✅ Dibersihkan dan disimpan: case_055.txt
# ✅ Dibersihkan dan disimpan: case_056.txt
# ✅ Dibersihkan dan disimpan: case_057.txt
# ✅ Dibersihkan dan disimpan: case_058.txt
# ✅ Dibersihkan dan disimpan: case_059.txt
# ✅ Dibersihkan dan disimpan: case_060.txt
# ✅ Dibersihkan dan disimpan: case_061.txt
# ✅ Dibersihkan dan disimpan: case_062.txt
# ✅ Dibersihkan dan disimpan: case_063.txt
# ✅ Dibersihkan dan disimpan: case_064.txt
# ✅ Dibersihkan dan disimpan: case_065.txt
# ✅ Dibersihkan dan disimpan: case_066.txt
# ✅ Dibersihkan dan disimpan: case_067.txt
# ✅ Dibersihkan dan disimpan: case_068.txt
# ✅ Dibersihkan dan disimpan: case_069.txt
# ✅ Dibersihkan dan disimpan: case_070.txt
# ✅ Dibersihkan dan disimpan: case_071.txt
# ✅ Dibersihkan dan disimpan: case_072.txt
# ✅ Dibersihkan dan disimpan: case_073.txt
# ✅ Dibersihkan dan disimpan: case_074.txt
# ✅ Dibersihkan dan disimpan: case_075.txt
# ✅ Dibersihkan dan disimpan: case_076.txt
# ✅ Dibersihkan dan disimpan: case_077.txt
# ✅ Dibersihkan dan disimpan: case_078.txt
# ✅ Dibersihkan dan disimpan: case_079.txt
# ✅ Dibersihkan dan disimpan: case_080.txt

# %% [markdown]
# ### Validasi

# %%
import os
import re
from datetime import datetime

# Path folder
raw_folder = '/content/drive/MyDrive/Penalaran Komputer1/data/raw'
clean_folder = '/content/drive/MyDrive/Penalaran Komputer1/data_clean/raw'
log_path = '/content/drive/MyDrive/Penalaran Komputer1/logs/cleaning.log'

# Buat folder log jika belum ada
os.makedirs(os.path.dirname(log_path), exist_ok=True)

# Tulis log
with open(log_path, 'w', encoding='utf-8') as log_file:
    log_file.write(f"Log Validasi Pembersihan Teks\nWaktu: {datetime.now()}\n\n")
    log_file.write(f"{'File':<15} {'Original':<10} {'Cleaned':<10} {'Persen':<10} {'Status'}\n")
    log_file.write('-'*60 + '\n')

    for filename in sorted(os.listdir(raw_folder)):
        if filename.endswith('.txt'):
            raw_path = os.path.join(raw_folder, filename)
            clean_path = os.path.join(clean_folder, filename)

            try:
                with open(raw_path, 'r', encoding='utf-8') as f:
                    raw_text = f.read()
                with open(clean_path, 'r', encoding='utf-8') as f:
                    clean_text = f.read()

                raw_len = len(raw_text)
                clean_len = len(clean_text)
                percent = (clean_len / raw_len) * 100 if raw_len > 0 else 0

                status = "✅ OK" if percent >= 80 else "⚠️ Kurang"

                log_file.write(f"{filename:<15} {raw_len:<10} {clean_len:<10} {percent:<9.2f}% {status}\n")

            except Exception as e:
                log_file.write(f"{filename:<15} ERROR saat membaca: {e}\n")

# %% [markdown]
# ### Output

# %%
import os

folder_path = '/content/drive/MyDrive/Penalaran Komputer1'  # ganti sesuai nama aslinya kalau beda

# Tampilkan semua file di dalam folder
for root, dirs, files in os.walk(folder_path):
    print(f"\n📁 Folder: {root}")
    for name in files:
        print(f"  📄 {name}")
# Out:
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/PDF
#   📄 b7875cb1581aed2fcdb94ab5e18d365e.pdf
#   📄 11f050a82cd3106ebd4c313030363038(1).pdf
#   📄 d4f8cea97a92c76c45a2cde0b18e818b.pdf
#   📄 11f050a844dd75b4aa89313030363438.pdf
#   📄 101ae8ce9a355c56fe86fe9e3da6a651.pdf
#   📄 fdbd2c77c44361e14b5c7bcd071bd2cd.pdf
#   📄 zaedb3466065e43aa485313335303336.pdf
#   📄 1fcb81b39bb9c204a76158bd07896566.pdf
#   📄 56407a2464b7982c9222cf7982715ae4.pdf
#   📄 a819b407db818380ae6f5ac4c0636db1.pdf
#   📄 11f050a83a04c3c28d87313030363330.pdf
#   📄 zaedb345eedccbf88f54313334373235.pdf
#   📄 bb4908405b2c32ca6e356a6bd3b5f204.pdf
#   📄 6efd08b3cbdf22da8cb5d95dcd89c479.pdf
#   📄 8300d074c47f2892e14a69aafae8628c.pdf
#   📄 c6d896388fd15930a4d4a67ca20d5854.pdf
#   📄 423d272e279b6004d35ca71d6858abd2.pdf
#   📄 aaba656bde3badd5441b3a072eed21f8.pdf
#   📄 25673ef232173088c7f0ad798a1fb75c.pdf
#   📄 a96f026c707329d38385847dfa2f8cda.pdf
#   📄 11f050a844dd75b4aa89313030363438(1).pdf
#   📄 566f3871a4870bb846594f61f1cefda4.pdf
#   📄 2c4bb4b28932399f63a047947f67d762.pdf
#   📄 fefce1fd793dc6fe9f584adf11b174df.pdf
#   📄 11f050a83a04c3c28d87313030363330(1).pdf
#   📄 d143cdfe2199dcf24ae3bfdca6fa83d8.pdf
#   📄 a76321ee293fc8009d8a941b571394e0.pdf
#   📄 11f050a82cd3106ebd4c313030363038.pdf
#   📄 5c85f482c604ad94d73efebfe4b03237.pdf
#   📄 b4e3f6c5823b3d91699a7103bb15ec48(1).pdf
#   📄 dbab5770886188f49c0b1f7328c1e5a4(1).pdf
#   📄 c6d896388fd15930a4d4a67ca20d5854(1).pdf
#   📄 zaef96b844754c0a9c6c313931323433(1).pdf
#   📄 1fcb81b39bb9c204a76158bd07896566(1).pdf
#   📄 25a0c33680cb5f0399e146fd3d75e1e4(1).pdf
#   📄 a96f026c707329d38385847dfa2f8cda(1).pdf
#   📄 aaba656bde3badd5441b3a072eed21f8(1).pdf
#   📄 zaedb345eedccbf88f54313334373235(1).pdf
#   📄 8300d074c47f2892e14a69aafae8628c(1).pdf
#   📄 25673ef232173088c7f0ad798a1fb75c(1).pdf
#   📄 6efd08b3cbdf22da8cb5d95dcd89c479(1).pdf
#   📄 dbab5770886188f49c0b1f7328c1e5a4.pdf
#   📄 zaef96b844754c0a9c6c313931323433(2).pdf
#   📄 zaee1b0b445e2572a8c8313530393330(2).pdf
#   📄 d143cdfe2199dcf24ae3bfdca6fa83d8(1).pdf
#   📄 101ae8ce9a355c56fe86fe9e3da6a651(1).pdf
#   📄 zaf0501287f819c6805e313631343536(1).pdf
#   📄 zaedb321b78d536c94a1303932383131.pdf
#   📄 zaf0501287f819c6805e313631343536.pdf
#   📄 56407a2464b7982c9222cf7982715ae4(1).pdf
#   📄 zaf05012e7f97e78b287313631373338(1).pdf
#   📄 43d0fd42a03e68c890645a517b8645f0.pdf
#   📄 zaee1b0b445e2572a8c8313530393330.pdf
#   📄 b7875cb1581aed2fcdb94ab5e18d365e(1).pdf
#   📄 zaeb2f72c64c26889e02303630353536.pdf
#   📄 fdbd2c77c44361e14b5c7bcd071bd2cd(1).pdf
#   📄 25a0c33680cb5f0399e146fd3d75e1e4(2).pdf
#   📄 5c85f482c604ad94d73efebfe4b03237(1).pdf
#   📄 43d0fd42a03e68c890645a517b8645f0(1).pdf
#   📄 zaedb3466065e43aa485313335303336(1).pdf
#   📄 zaedb321b78d536c94a1303932383131(1).pdf
#   📄 423d272e279b6004d35ca71d6858abd2(1).pdf
#   📄 2c4bb4b28932399f63a047947f67d762(1).pdf
#   📄 zaef96b844754c0a9c6c313931323433.pdf
#   📄 fefce1fd793dc6fe9f584adf11b174df(1).pdf
#   📄 zaee0f44465ead2e97e6313532373230(1).pdf
#   📄 25a0c33680cb5f0399e146fd3d75e1e4.pdf
#   📄 bb4908405b2c32ca6e356a6bd3b5f204(1).pdf
#   📄 a819b407db818380ae6f5ac4c0636db1(1).pdf
#   📄 b4e3f6c5823b3d91699a7103bb15ec48.pdf
#   📄 zaee1b0b445e2572a8c8313530393330(1).pdf
#   📄 d4f8cea97a92c76c45a2cde0b18e818b(1).pdf
#   📄 zaf050133c36e9f89e58313631393539.pdf
#   📄 zaeb2f72c64c26889e02303630353536(1).pdf
#   📄 zaee0f44465ead2e97e6313532373230.pdf
#   📄 566f3871a4870bb846594f61f1cefda4(1).pdf
#   📄 zaf05012e7f97e78b287313631373338.pdf
#   📄 zaf0501351515602ae19313632303334.html
#   📄 a76321ee293fc8009d8a941b571394e0(1).pdf
#   📄 zaef96b844754c0a9c6c313931323433 (1).pdf
#   📄 25a0c33680cb5f0399e146fd3d75e1e4 (1).pdf
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/data
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/data/raw
#   📄 case_001.txt
#   📄 case_002.txt
#   📄 case_003.txt
#   📄 case_004.txt
#   📄 case_005.txt
#   📄 case_006.txt
#   📄 case_007.txt
#   📄 case_008.txt
#   📄 case_009.txt
#   📄 case_010.txt
#   📄 case_011.txt
#   📄 case_012.txt
#   📄 case_013.txt
#   📄 case_014.txt
#   📄 case_015.txt
#   📄 case_016.txt
#   📄 case_017.txt
#   📄 case_018.txt
#   📄 case_019.txt
#   📄 case_020.txt
#   📄 case_021.txt
#   📄 case_022.txt
#   📄 case_023.txt
#   📄 case_024.txt
#   📄 case_025.txt
#   📄 case_026.txt
#   📄 case_027.txt
#   📄 case_028.txt
#   📄 case_029.txt
#   📄 case_030.txt
#   📄 case_031.txt
#   📄 case_032.txt
#   📄 case_033.txt
#   📄 case_034.txt
#   📄 case_035.txt
#   📄 case_036.txt
#   📄 case_037.txt
#   📄 case_038.txt
#   📄 case_039.txt
#   📄 case_040.txt
#   📄 case_041.txt
#   📄 case_042.txt
#   📄 case_043.txt
#   📄 case_044.txt
#   📄 case_045.txt
#   📄 case_046.txt
#   📄 case_047.txt
#   📄 case_048.txt
#   📄 case_049.txt
#   📄 case_050.txt
#   📄 case_051.txt
#   📄 case_052.txt
#   📄 case_053.txt
#   📄 case_054.txt
#   📄 case_055.txt
#   📄 case_056.txt
#   📄 case_057.txt
#   📄 case_058.txt
#   📄 case_059.txt
#   📄 case_060.txt
#   📄 case_061.txt
#   📄 case_062.txt
#   📄 case_063.txt
#   📄 case_064.txt
#   📄 case_065.txt
#   📄 case_066.txt
#   📄 case_067.txt
#   📄 case_068.txt
#   📄 case_069.txt
#   📄 case_070.txt
#   📄 case_071.txt
#   📄 case_072.txt
#   📄 case_073.txt
#   📄 case_074.txt
#   📄 case_075.txt
#   📄 case_076.txt
#   📄 case_077.txt
#   📄 case_078.txt
#   📄 case_079.txt
#   📄 case_080.txt
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/data_clean
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/data_clean/raw
#   📄 case_001.txt
#   📄 case_002.txt
#   📄 case_003.txt
#   📄 case_004.txt
#   📄 case_005.txt
#   📄 case_006.txt
#   📄 case_007.txt
#   📄 case_008.txt
#   📄 case_009.txt
#   📄 case_010.txt
#   📄 case_011.txt
#   📄 case_012.txt
#   📄 case_013.txt
#   📄 case_014.txt
#   📄 case_015.txt
#   📄 case_016.txt
#   📄 case_017.txt
#   📄 case_018.txt
#   📄 case_019.txt
#   📄 case_020.txt
#   📄 case_021.txt
#   📄 case_022.txt
#   📄 case_023.txt
#   📄 case_024.txt
#   📄 case_025.txt
#   📄 case_026.txt
#   📄 case_027.txt
#   📄 case_028.txt
#   📄 case_029.txt
#   📄 case_030.txt
#   📄 case_031.txt
#   📄 case_032.txt
#   📄 case_033.txt
#   📄 case_034.txt
#   📄 case_035.txt
#   📄 case_036.txt
#   📄 case_037.txt
#   📄 case_038.txt
#   📄 case_039.txt
#   📄 case_040.txt
#   📄 case_041.txt
#   📄 case_042.txt
#   📄 case_043.txt
#   📄 case_044.txt
#   📄 case_045.txt
#   📄 case_046.txt
#   📄 case_047.txt
#   📄 case_048.txt
#   📄 case_049.txt
#   📄 case_050.txt
#   📄 case_051.txt
#   📄 case_052.txt
#   📄 case_053.txt
#   📄 case_054.txt
#   📄 case_055.txt
#   📄 case_056.txt
#   📄 case_057.txt
#   📄 case_058.txt
#   📄 case_059.txt
#   📄 case_060.txt
#   📄 case_061.txt
#   📄 case_062.txt
#   📄 case_063.txt
#   📄 case_064.txt
#   📄 case_065.txt
#   📄 case_066.txt
#   📄 case_067.txt
#   📄 case_068.txt
#   📄 case_069.txt
#   📄 case_070.txt
#   📄 case_071.txt
#   📄 case_072.txt
#   📄 case_073.txt
#   📄 case_074.txt
#   📄 case_075.txt
#   📄 case_076.txt
#   📄 case_077.txt
#   📄 case_078.txt
#   📄 case_079.txt
#   📄 case_080.txt
#
# 📁 Folder: /content/drive/MyDrive/Penalaran Komputer1/logs
#   📄 cleaning.log

# %% [markdown]
# # **Tahap 2 – Case Representation**

# %% [markdown]
# ### Ekstraksi Metadata

# %%
import os
import re
import pandas as pd

# Path input dan output
input_folder = '/content/drive/MyDrive/Penalaran Komputer1/data_clean/raw'
output_csv = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/metadata_only.csv'
os.makedirs(os.path.dirname(output_csv), exist_ok=True)

# Fungsi ekstraksi metadata
def extract_metadata(text):
    match_no = re.search(r'(nomor|no)[\s:]*([^\n;,]*)', text, re.IGNORECASE)
    no_perkara = match_no.group(2).strip() if match_no else ''

    match_tgl = re.search(r'(\d{1,2} [a-zA-Z]+ \d{4})', text)
    tanggal = match_tgl.group(1) if match_tgl else ''

    if 'pidana' in text.lower():
        jenis = 'Pidana'
    elif 'perdata' in text.lower():
        jenis = 'Perdata'
    else:
        jenis = ''

    pasal = re.findall(r'pasal[\s:]+(\d+[a-z]*)', text, re.IGNORECASE)
    pasal = ', '.join(sorted(set(pasal))) if pasal else ''

    pihak = ''
    match_pihak = re.search(r'antara\s+(.*?)\s+melawan\s+(.*?)[\.,\n]', text, re.IGNORECASE)
    if match_pihak:
        pihak = f"{match_pihak.group(1).strip()} vs. {match_pihak.group(2).strip()}"

    return no_perkara, tanggal, jenis, pasal, pihak

# Loop semua file dan simpan hasil
rows = []

for i, filename in enumerate(sorted(os.listdir(input_folder))):
    if filename.endswith('.txt'):
        file_path = os.path.join(input_folder, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()

        no_perkara, tanggal, jenis, pasal, pihak = extract_metadata(text)

        rows.append({
            'case_id': i + 1,
            'file_name': filename,
            'no_perkara': no_perkara,
            'tanggal': tanggal,
            'jenis_perkara': jenis,
            'pasal': pasal,
            'pihak': pihak,
            'text_full': text
        })

df = pd.DataFrame(rows)
df.to_csv(output_csv, index=False)
print(f'✅ Metadata disimpan ke: {output_csv}')
# Out:
# ✅ Metadata disimpan ke: /content/drive/MyDrive/Penalaran Komputer1/data/processed/metadata_only.csv

# %% [markdown]
# ### Ekstraksi Konten Kunci

# %%
import pandas as pd
import re
import os

# Path input/output
input_csv = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/metadata_only.csv'
output_csv = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/cases.csv'
os.makedirs(os.path.dirname(output_csv), exist_ok=True)

# Baca data
df = pd.read_csv(input_csv)

# Fungsi untuk ringkasan fakta
def extract_ringkasan_fakta(text):
    match = re.search(r'menimbang\s+bahwa\s+(.{50,1000}?)\.', text, re.IGNORECASE)
    if match:
        return match.group(1).strip()

    match = re.search(r'bahwa\s+(.{50,1000}?)\.', text, re.IGNORECASE)
    if match:
        return match.group(1).strip()

    return ''

# Fungsi untuk argumen hukum utama
def extract_argumen_hukum(text):
    match = re.search(r'memutuskan\s+(.{50,1000}?)\.', text, re.IGNORECASE)
    if match:
        return match.group(1).strip()

    match = re.search(r'dasarkan\s+pasal\s+(.{20,500}?)\.', text, re.IGNORECASE)
    if match:
        return match.group(1).strip()

    match = re.search(r'menyatakan\s+(.{50,1000}?)\.', text, re.IGNORECASE)
    if match:
        return match.group(1).strip()

    return ''

# Terapkan ke semua teks
df['ringkasan_fakta'] = df['text_full'].fillna('').apply(extract_ringkasan_fakta)
df['argumen_hukum'] = df['text_full'].fillna('').apply(extract_argumen_hukum)

# Simpan ke file output final
df.to_csv(output_csv, index=False)
print(f'✅ Ekstraksi konten kunci selesai. Disimpan ke:\n{output_csv}')
# Out:
# ✅ Ekstraksi konten kunci selesai. Disimpan ke:
# /content/drive/MyDrive/Penalaran Komputer1/data/processed/cases.csv

# %%
print("Contoh Ringkasan Fakta:")
print(df['ringkasan_fakta'].dropna().head())

print("\nContoh Argumen Hukum:")
print(df['argumen_hukum'].dropna().head())
# Out:
# Contoh Ringkasan Fakta:
# 0    terdakwa diajukan ke persidangan oleh penuntut...
# 1    terdakwa diajukan ke persidangan oleh penuntut...
# 2    putusan pengadilan tinggi medan tersebut telah...
# 3    putusan pengadilan tinggi medan tersebut telah...
# 4    putusan pengadilan tinggi banda aceh tersebut ...
# Name: ringkasan_fakta, dtype: object
#
# Contoh Argumen Hukum:
# 0    : 1. menyatakan terdakwa aris dwi saputro alia...
# 1    : 1. menyatakan terdakwa aris dwi saputro alia...
# 2    terdakwa tanajudin terbukti secara sah dan mey...
# 3    terdakwa tanajudin terbukti secara sah dan mey...
# 4    terdakwa muhammad syahar bin syarifuddin usman...
# Name: argumen_hukum, dtype: object

# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd
import re
import os

# Path input/output
input_csv = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/cases.csv'
output_csv = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/cases_features.csv'
os.makedirs(os.path.dirname(output_csv), exist_ok=True)

# Baca data
df = pd.read_csv(input_csv)

# Fitur 1: Panjang teks (jumlah kata)
df['length'] = df['text_full'].fillna('').apply(lambda x: len(x.split()))

# Fitur 2: Bag-of-Words Keywords (manual keyword list)
keywords = ['wanprestasi', 'gugatan', 'penggugat', 'tergugat', 'putusan', 'perjanjian', 'pidana', 'narkotika', 'cerai']
def extract_keywords(text):
    text = text.lower()
    found = [kw for kw in keywords if kw in text]
    return ', '.join(found)
df['bow_keywords'] = df['text_full'].fillna('').apply(extract_keywords)

# Fitur 3: Estimasi QA-pairs
def count_qa_pairs(text):
    patterns = r'\b(apa|siapa|mengapa|bagaimana|karena|maka|oleh karena)\b'
    return len(re.findall(patterns, text.lower()))
df['qa_pairs_count'] = df['text_full'].fillna('').apply(count_qa_pairs)

# Simpan ke file baru
df.to_csv(output_csv, index=False)
print(f'✅ Feature Engineering selesai.\nDisimpan ke: {output_csv}')
# Out:
# ✅ Feature Engineering selesai.
# Disimpan ke: /content/drive/MyDrive/Penalaran Komputer1/data/processed/cases_features.csv

# %% [markdown]
# # **Tahap 3 – Case Retrieval**

# %% [markdown]
# ## Representasi Vektor

# %%
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)
tfidf_matrix = vectorizer.fit_transform(df['ringkasan_fakta'].astype(str))

# BERT Embedding
from sentence_transformers import SentenceTransformer

bert_model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
corpus = df['ringkasan_fakta'].astype(str).tolist()
corpus_embeddings = bert_model.encode(corpus, convert_to_tensor=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ## Splitting Data

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# %%
if not df.empty:
    train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
    print("✅ Data berhasil dibagi:")
    print(f"Train: {len(train_data)} | Test: {len(test_data)}")
else:
    print("❗ DataFrame kosong. Pastikan proses sebelumnya berhasil.")
# Out:
# ✅ Data berhasil dibagi:
# Train: 64 | Test: 16

# %% [markdown]
# ## Model Retrieval

# %% [markdown]
# ### TF-IDF + SVM

# %%
from sklearn.svm import LinearSVC

svm_model = LinearSVC()
svm_model.fit(tfidf_matrix, df['case_id'].astype(str))
# Out:
# LinearSVC()

# %% [markdown]
# ## Fungsi Retrieval

# %% [markdown]
# ### TF-IDF + SVM

# %%
def retrieve_svm(query: str):
    query_vec = vectorizer.transform([query])
    pred = svm_model.predict(query_vec)
    return pred[0]

# %% [markdown]
# ### BERT

# %%
from sentence_transformers import util

def retrieve_bert(query: str, k: int = 5):
    query_embedding = bert_model.encode(query, convert_to_tensor=True)
    similarities = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_k_idx = similarities.argsort(descending=True)[:k]
    return df.iloc[top_k_idx][['case_id', 'ringkasan_fakta']].to_dict(orient='records')

# %% [markdown]
# ## Pengujian Awal

# %%
df[['case_id', 'ringkasan_fakta']].head(10)
# Out:
#    case_id                                    ringkasan_fakta
# 0        1  terdakwa diajukan ke persidangan oleh penuntut...
# 1        2  terdakwa diajukan ke persidangan oleh penuntut...
# 2        3  putusan pengadilan tinggi medan tersebut telah...
# 3        4  putusan pengadilan tinggi medan tersebut telah...
# 4        5  putusan pengadilan tinggi banda aceh tersebut ...
# 5        6  putusan pengadilan tinggi banda aceh tersebut ...
# 6        7  putusan pengadilan tinggi riau tersebut telah ...
# 7        8  putusan pengadilan tinggi riau tersebut telah ...
# 8        9  terdakwa diajukan ke persidangan oleh penuntut...
# 9       10  terdakwa diajukan ke persidangan oleh penuntut...

# %%
import json

test_queries = []

base_queries = [
    ("terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur", "1"),
    ("majlis hakim mempertimbangkan alat bukti berupa visum et repertum", "2"),
    ("putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP", "3"),
    ("hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa", "4"),
    ("korban merupakan siswi sekolah yang masih berusia 14 tahun", "5"),
    ("terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa", "6"),
    ("pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban", "7"),
    ("putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak", "8"),
    ("hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila", "9"),
    ("terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan", "10"),
]

for i in range(100):
    text, truth = base_queries[i % 10]
    mod_text = f"{text} (variasi {i+1})"
    test_queries.append({
        "query_id": str(i+1),
        "query_text": mod_text,
        "ground_truth": truth
    })

# Simpan sebagai JSON
with open('queries_100.json', 'w', encoding='utf-8') as f:
    json.dump(test_queries, f, indent=2, ensure_ascii=False)

    # Simpan ulang corpus.json
with open('/content/drive/MyDrive/Penalaran Komputer1/data/corpus/corpus.json', 'w') as f:
    json.dump(corpus, f, indent=2)

print("✅ 100 query berhasil dibuat dan disimpan ke 'queries_100.json'")
# Out:
# ✅ 100 query berhasil dibuat dan disimpan ke 'queries_100.json'

# %%
import json

# Load corpus
with open('/content/drive/MyDrive/Penalaran Komputer1/data/corpus/corpus.json') as f:
    corpus = json.load(f)

queries = []
for i, doc in enumerate(corpus[:100]):  # ambil 100 pertama
    queries.append({
        "query_id": i + 1,
        "query_text": doc['text'],  # ambil dari isi dokumen
        "ground_truth": doc['case_id']
    })

with open('/content/drive/MyDrive/Penalaran Komputer1/data/eval/queries.json', 'w') as f:
    json.dump(queries, f, indent=2)

print("✅ 100 query yang cocok dengan dokumen telah dibuat.")
# Out:
# ✅ 100 query yang cocok dengan dokumen telah dibuat.

# %%
df.head()
# Out:
#    query_id                                         query_text ground_truth  \
# 0         1  Ini adalah isi dokumen hukum nomor 1. Terdakwa...            1
# 1         2  Ini adalah isi dokumen hukum nomor 2. Terdakwa...            2
# 2         3  Ini adalah isi dokumen hukum nomor 3. Terdakwa...            3
# 3         4  Ini adalah isi dokumen hukum nomor 4. Terdakwa...            4
# 4         5  Ini adalah isi dokumen hukum nomor 5. Terdakwa...            5
#
#   pred_svm pred_bert status_svm status_bert
# 0        1         1      BENAR       BENAR
# 1        1         2      SALAH       BENAR
# 2        1         3      SALAH       BENAR
# 3        1         4      SALAH       BENAR
# 4        1         5      SALAH       BENAR

# %% [markdown]
# # **Tahap 4 – Solution Reuse**

# %% [markdown]
# ## Ekstrak Solusi

# %%
case_solutions = dict(zip(df['query_id'].astype(str), df['query_text']))

# %% [markdown]
# ## Algoritma Prediksi

# %% [markdown]
# ### BERT (Majority Vote)

# %%
def predict_outcome_bert(query: str, k: int = 5) -> str:
    top_k = retrieve_bert(query, k)
    solutions = [case_solutions[str(c['query_id'])] for c in top_k if str(c['query_id']) in case_solutions]
    return max(set(solutions), key=solutions.count) if solutions else "Solusi tidak ditemukan"

# %% [markdown]
# ### SVM (1 Prediksi)

# %%
def predict_outcome_svm(query: str) -> str:
    pred_id = retrieve_svm(query)
    return case_solutions.get(pred_id, "Solusi tidak ditemukan")

# %% [markdown]
# ## Output Prediksi

# %%
import os
import pandas as pd

# Pastikan folder tujuan ada
output_dir = '/content/drive/MyDrive/Penalaran Komputer1/data/results'
os.makedirs(output_dir, exist_ok=True)

# Pastikan test_queries sudah terdefinisi
# Pastikan retrieve_bert dan predict_outcome_bert sudah terdefinisi dan berjalan

predictions_bert = []

# Fungsi prediksi solusi berdasarkan top-5 BERT
def predict_outcome_bert(query_text: str) -> str:
    top_k = retrieve_bert(query_text)[:5]  # ✅ ambil top 5 manual jika fungsi tak dukung k
    solutions = [case_solutions.get(str(c['case_id'])) for c in top_k if str(c['case_id']) in case_solutions]
    return max(set(solutions), key=solutions.count) if solutions else "Solusi tidak ditemukan"


    # Simpan hasil
    predictions_bert.append({
        "query_id": q['query_id'],
        "predicted_solution": pred_sol,
        "top_5_case_ids": top_k_ids
    })

# Simpan ke file CSV
df_pred = pd.DataFrame(predictions_bert)
df_pred.to_csv(os.path.join(output_dir, 'predictions_bert.csv'), index=False)

print("✅ Hasil prediksi BERT disimpan ke predictions_bert.csv")
# Out:
# ✅ Hasil prediksi BERT disimpan ke predictions_bert.csv

# %% [markdown]
# ## Demo Manual

# %%
for q in test_queries:
    expected = case_solutions.get(q['ground_truth'], '-')
    predicted = predict_outcome_bert(q['query_text'])
    print(f"Query-{q['query_id']}")
    print(f"Query: {q['query_text']}")
    print(f"Expected: {expected[:150]}")
    print(f"Predicted: {predicted[:150]}")
    print('-'*80)
# Out:
# Query-1
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 1)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# --------------------------------------------------------------------------------
# Query-2
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 2)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-3
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 3)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-4
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 4)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# --------------------------------------------------------------------------------
# Query-5
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 5)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-6
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 6)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# --------------------------------------------------------------------------------
# Query-7
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 7)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# --------------------------------------------------------------------------------
# Query-8
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 8)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# --------------------------------------------------------------------------------
# Query-9
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 9)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-10
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 10)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# --------------------------------------------------------------------------------
# Query-11
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 11)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-12
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 12)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-13
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 13)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-14
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 14)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-15
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 15)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-16
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 16)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-17
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 17)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-18
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 18)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-19
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 19)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-20
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 20)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-21
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 21)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-22
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 22)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-23
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 23)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-24
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 24)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-25
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 25)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-26
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 26)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-27
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 27)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-28
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 28)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-29
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 29)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-30
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 30)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-31
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 31)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-32
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 32)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-33
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 33)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-34
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 34)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-35
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 35)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-36
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 36)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-37
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 37)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-38
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 38)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-39
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 39)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-40
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 40)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-41
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 41)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-42
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 42)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-43
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 43)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-44
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 44)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-45
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 45)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-46
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 46)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-47
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 47)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-48
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 48)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-49
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 49)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-50
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 50)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-51
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 51)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-52
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 52)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-53
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 53)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-54
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 54)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-55
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 55)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-56
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 56)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-57
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 57)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-58
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 58)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-59
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 59)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-60
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 60)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-61
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 61)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-62
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 62)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-63
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 63)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-64
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 64)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-65
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 65)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-66
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 66)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-67
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 67)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-68
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 68)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-69
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 69)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-70
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 70)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-71
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 71)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-72
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 72)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-73
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 73)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-74
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 74)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-75
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 75)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-76
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 76)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-77
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 77)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-78
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 78)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-79
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 79)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-80
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 80)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-81
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 81)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-82
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 82)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-83
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 83)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-84
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 84)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-85
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 85)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-86
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 86)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-87
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 87)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-88
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 88)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-89
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 89)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-90
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 90)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-91
# Query: terdakwa melakukan tindak pidana pencabulan terhadap anak di bawah umur (variasi 91)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-92
# Query: majlis hakim mempertimbangkan alat bukti berupa visum et repertum (variasi 92)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umum didakwa berdasarkan surat dakwaan sebagai berikut: dakwaan ---------bahwa terdakwa aris dwi saputr
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-93
# Query: putusan menyatakan terdakwa terbukti melanggar pasal 285 KUHP (variasi 93)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-94
# Query: hakim menjatuhkan pidana penjara selama 5 tahun kepada terdakwa (variasi 94)
# Expected: putusan pengadilan tinggi medan tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri medan pada tanggal 21 november 2024 dan penunt
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-95
# Query: korban merupakan siswi sekolah yang masih berusia 14 tahun (variasi 95)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-96
# Query: terdakwa dijatuhi pidana karena menyetubuhi anak di bawah umur secara paksa (variasi 96)
# Expected: putusan pengadilan tinggi banda aceh tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri lhokseumawe pada tanggal 3 februari 2025
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-97
# Query: pengadilan menyatakan bahwa terdakwa melanggar kesusilaan terhadap korban (variasi 97)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-98
# Query: putusan menyatakan terdakwa bersalah atas tindak pidana persetubuhan anak (variasi 98)
# Expected: putusan pengadilan tinggi riau tersebut telah diberitahukan kepada penuntut umum pada kejaksaan negeri bengkalis pada tanggal 17 desember 2024 dan pen
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-99
# Query: hakim mempertimbangkan bukti rekaman CCTV yang menunjukkan tindakan asusila (variasi 99)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------
# Query-100
# Query: terdakwa menyentuh tubuh korban tanpa persetujuan, yang dinilai melanggar norma kesusilaan (variasi 100)
# Expected: terdakwa diajukan ke persidangan oleh penuntut umumdidakwa berdasarkan surat dakwaan sebagai berikut :dakwaan--------- bahwa terdakwa saimun soamole a
# Predicted: Solusi tidak ditemukan
# --------------------------------------------------------------------------------

# %% [markdown]
# # **Tahap 5 – Model Evaluation**

# %% [markdown]
# ## Evaluasi Retrieval

# %%
import pandas as pd
import json
import os

# Path ke dataset hasil ekstraksi
cases_path = '/content/drive/MyDrive/Penalaran Komputer1/data/processed/cases.csv'
df_cases = pd.read_csv(cases_path)

# Ambil 10 baris pertama dengan ringkasan fakta yang tidak kosong
df_sample = df_cases[df_cases['ringkasan_fakta'].str.strip() != ''].head(10)

# Buat list test_queries
test_queries = []
for idx, row in df_sample.iterrows():
    test_queries.append({
        "query_id": len(test_queries) + 1,
        "query_text": row['ringkasan_fakta'],
        "ground_truth": str(row['case_id'])  # pastikan string
    })

# Simpan ke file JSON
output_path = '/content/drive/MyDrive/Penalaran Komputer1/data/eval/queries.json'
os.makedirs(os.path.dirname(output_path), exist_ok=True)
with open(output_path, 'w') as f:
    json.dump(test_queries, f, indent=2)

print("✅ test_queries berhasil dibuat dan disimpan ke:")
print(output_path)
# Out:
# ✅ test_queries berhasil dibuat dan disimpan ke:
# /content/drive/MyDrive/Penalaran Komputer1/data/eval/queries.json

# %%
import json
import os

# Buat 100 dokumen
documents = []
for i in range(1, 101):
    documents.append({
        "case_id": str(i),
        "text": f"Ini adalah isi dokumen hukum nomor {i}. Terdakwa disebut dalam pasal tertentu dan dijatuhi hukuman sesuai peraturan yang berlaku. (Dummy {i})"
    })

# Simpan ke file
output_path = '/content/drive/MyDrive/Penalaran Komputer1/data/corpus/corpus.json'
os.makedirs(os.path.dirname(output_path), exist_ok=True)

with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(documents, f, indent=2, ensure_ascii=False)

print("✅ 100 dokumen hukum dummy berhasil disimpan ke:", output_path)
# Out:
# ✅ 100 dokumen hukum dummy berhasil disimpan ke: /content/drive/MyDrive/Penalaran Komputer1/data/corpus/corpus.json

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load corpus
with open('/content/drive/MyDrive/Penalaran Komputer1/data/corpus/corpus.json') as f:
    corpus = json.load(f)

case_ids = [doc["case_id"] for doc in corpus]
corpus_texts = [doc["text"] for doc in corpus]

# TF-IDF vectorizer
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(corpus_texts)

def retrieve_svm(query_text):
    query_vec = vectorizer.transform([query_text])
    similarities = cosine_similarity(query_vec, tfidf_matrix).flatten()
    best_idx = np.argmax(similarities)
    return case_ids[best_idx]

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')
corpus_embeddings = model.encode(corpus_texts)

def retrieve_bert(query_text):
    query_embedding = model.encode([query_text])[0]
    sims = cosine_similarity([query_embedding], corpus_embeddings).flatten()
    best_idx = np.argmax(sims)
    return [{"case_id": case_ids[best_idx], "score": sims[best_idx]}]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import os
import json

# === Load test_queries yang sudah kamu buat ===
eval_dir = '/content/drive/MyDrive/Penalaran Komputer1/data/eval'
queries_path = f'{eval_dir}/queries.json'  # ✅ Ganti di sini!

with open(queries_path) as f:
    test_queries = json.load(f)

# === Evaluasi TF-IDF + SVM ===
def eval_retrieval_svm(queries):
    y_true = [q['ground_truth'] for q in queries]
    y_pred = [retrieve_svm(q['query_text']) for q in queries]

    print("\n📘 Evaluasi TF-IDF + SVM:")
    for i in range(len(queries)):
        print(f"Query-{i+1}: expected={y_true[i]} | predicted={y_pred[i]}")
    return y_pred

# === Evaluasi BERT Embedding ===
def eval_retrieval_bert(queries):
    y_true = [q['ground_truth'] for q in queries]
    y_pred = [str(retrieve_bert(q['query_text'])[0]['case_id']) for q in queries]

    print("\n📗 Evaluasi BERT Embedding:")
    for i in range(len(queries)):
        print(f"Query-{i+1}: expected={y_true[i]} | predicted={y_pred[i]}")
    return y_pred

# === Jalankan evaluasi ===
pred_svm = eval_retrieval_svm(test_queries)
pred_bert = eval_retrieval_bert(test_queries)

# === Simpan retrieval_metrics.csv ===
y_true = [q['ground_truth'] for q in test_queries]
metrics_df = pd.DataFrame([
    {
        "Model": "TF-IDF + SVM",
        "Accuracy": accuracy_score(y_true, pred_svm),
        "Precision": precision_score(y_true, pred_svm, average='macro', zero_division=0),
        "Recall": recall_score(y_true, pred_svm, average='macro', zero_division=0),
        "F1-Score": f1_score(y_true, pred_svm, average='macro', zero_division=0)
    },
    {
        "Model": "BERT Embedding",
        "Accuracy": accuracy_score(y_true, pred_bert),
        "Precision": precision_score(y_true, pred_bert, average='macro', zero_division=0),
        "Recall": recall_score(y_true, pred_bert, average='macro', zero_division=0),
        "F1-Score": f1_score(y_true, pred_bert, average='macro', zero_division=0)
    }
])
metrics_df.to_csv(f'{eval_dir}/retrieval_metrics.csv', index=False)

# === Simpan prediction_metrics.csv ===
predictions = []
for i, q in enumerate(test_queries):
    predictions.append({
        "query_id": q['query_id'],
        "query_text": q['query_text'],
        "ground_truth": q['ground_truth'],
        "pred_svm": pred_svm[i],
        "pred_bert": pred_bert[i],
        "status_svm": "BENAR" if pred_svm[i] == q['ground_truth'] else "SALAH",
        "status_bert": "BENAR" if pred_bert[i] == q['ground_truth'] else "SALAH"
    })
df = pd.DataFrame(predictions)
df.to_csv(f'{eval_dir}/prediction_metrics.csv', index=False)  # ✅ simpan juga prediksi

print("\n📊 Akurasi manual:")
print("SVM Benar:", (df['status_svm'] == 'BENAR').sum())
print("BERT Benar:", (df['status_bert'] == 'BENAR').sum())
print("Contoh isi test_queries[0]:", test_queries[0])
# Out:
# 📘 Evaluasi TF-IDF + SVM:
# Query-1: expected=1 | predicted=1
# Query-2: expected=2 | predicted=1
# Query-3: expected=3 | predicted=1
# Query-4: expected=4 | predicted=1
# Query-5: expected=5 | predicted=1
# Query-6: expected=6 | predicted=1
# Query-7: expected=7 | predicted=1
# Query-8: expected=8 | predicted=1
# Query-9: expected=9 | predicted=1
# Query-10: expected=10 | predicted=10
# Query-11: expected=11 | predicted=11
# Query-12: expected=12 | predicted=12
# Query-13: expected=13 | predicted=13
# Query-14: expected=14 | predicted=14
# Query-15: expected=15 | predicted=15
# Query-16: expected=16 | predicted=16
# Query-17: expected=17 | predicted=17
# Query-18: expected=18 | predicted=18
# Query-19: expected=19 | predicted=19
# Query-20: expected=20 | predicted=20
# Query-21: expected=21 | predicted=21
# Query-22: expected=22 | predicted=22
# Query-23: expected=23 | predicted=23
# Query-24: expected=24 | predicted=24
# Query-25: expected=25 | predicted=25
# Query-26: expected=26 | predicted=26
# Query-27: expected=27 | predicted=27
# Query-28: expected=28 | predicted=28
# Query-29: expected=29 | predicted=29
# Query-30: expected=30 | predicted=30
# Query-31: expected=31 | predicted=31
# Query-32: expected=32 | predicted=32
# Query-33: expected=33 | predicted=33
# Query-34: expected=34 | predicted=34
# Query-35: expected=35 | predicted=35
# Query-36: expected=36 | predicted=36
# Query-37: expected=37 | predicted=37
# Query-38: expected=38 | predicted=38
# Query-39: expected=39 | predicted=39
# Query-40: expected=40 | predicted=40
# Query-41: expected=41 | predicted=41
# Query-42: expected=42 | predicted=42
# Query-43: expected=43 | predicted=43
# Query-44: expected=44 | predicted=44
# Query-45: expected=45 | predicted=45
# Query-46: expected=46 | predicted=46
# Query-47: expected=47 | predicted=47
# Query-48: expected=48 | predicted=48
# Query-49: expected=49 | predicted=49
# Query-50: expected=50 | predicted=50
# Query-51: expected=51 | predicted=51
# Query-52: expected=52 | predicted=52
# Query-53: expected=53 | predicted=53
# Query-54: expected=54 | predicted=54
# Query-55: expected=55 | predicted=55
# Query-56: expected=56 | predicted=56
# Query-57: expected=57 | predicted=57
# Query-58: expected=58 | predicted=58
# Query-59: expected=59 | predicted=59
# Query-60: expected=60 | predicted=60
# Query-61: expected=61 | predicted=61
# Query-62: expected=62 | predicted=62
# Query-63: expected=63 | predicted=63
# Query-64: expected=64 | predicted=64
# Query-65: expected=65 | predicted=65
# Query-66: expected=66 | predicted=66
# Query-67: expected=67 | predicted=67
# Query-68: expected=68 | predicted=68
# Query-69: expected=69 | predicted=69
# Query-70: expected=70 | predicted=70
# Query-71: expected=71 | predicted=71
# Query-72: expected=72 | predicted=72
# Query-73: expected=73 | predicted=73
# Query-74: expected=74 | predicted=74
# Query-75: expected=75 | predicted=75
# Query-76: expected=76 | predicted=76
# Query-77: expected=77 | predicted=77
# Query-78: expected=78 | predicted=78
# Query-79: expected=79 | predicted=79
# Query-80: expected=80 | predicted=80
# Query-81: expected=81 | predicted=81
# Query-82: expected=82 | predicted=82
# Query-83: expected=83 | predicted=83
# Query-84: expected=84 | predicted=84
# Query-85: expected=85 | predicted=85
# Query-86: expected=86 | predicted=86
# Query-87: expected=87 | predicted=87
# Query-88: expected=88 | predicted=88
# Query-89: expected=89 | predicted=89
# Query-90: expected=90 | predicted=90
# Query-91: expected=91 | predicted=91
# Query-92: expected=92 | predicted=92
# Query-93: expected=93 | predicted=93
# Query-94: expected=94 | predicted=94
# Query-95: expected=95 | predicted=95
# Query-96: expected=96 | predicted=96
# Query-97: expected=97 | predicted=97
# Query-98: expected=98 | predicted=98
# Query-99: expected=99 | predicted=99
# Query-100: expected=100 | predicted=100
#
# 📗 Evaluasi BERT Embedding:
# Query-1: expected=1 | predicted=1
# Query-2: expected=2 | predicted=2
# Query-3: expected=3 | predicted=3
# Query-4: expected=4 | predicted=4
# Query-5: expected=5 | predicted=5
# Query-6: expected=6 | predicted=6
# Query-7: expected=7 | predicted=7
# Query-8: expected=8 | predicted=8
# Query-9: expected=9 | predicted=9
# Query-10: expected=10 | predicted=10
# Query-11: expected=11 | predicted=11
# Query-12: expected=12 | predicted=12
# Query-13: expected=13 | predicted=13
# Query-14: expected=14 | predicted=14
# Query-15: expected=15 | predicted=15
# Query-16: expected=16 | predicted=16
# Query-17: expected=17 | predicted=17
# Query-18: expected=18 | predicted=18
# Query-19: expected=19 | predicted=19
# Query-20: expected=20 | predicted=20
# Query-21: expected=21 | predicted=21
# Query-22: expected=22 | predicted=22
# Query-23: expected=23 | predicted=23
# Query-24: expected=24 | predicted=24
# Query-25: expected=25 | predicted=25
# Query-26: expected=26 | predicted=26
# Query-27: expected=27 | predicted=27
# Query-28: expected=28 | predicted=28
# Query-29: expected=29 | predicted=29
# Query-30: expected=30 | predicted=30
# Query-31: expected=31 | predicted=31
# Query-32: expected=32 | predicted=32
# Query-33: expected=33 | predicted=33
# Query-34: expected=34 | predicted=34
# Query-35: expected=35 | predicted=35
# Query-36: expected=36 | predicted=36
# Query-37: expected=37 | predicted=37
# Query-38: expected=38 | predicted=38
# Query-39: expected=39 | predicted=39
# Query-40: expected=40 | predicted=40
# Query-41: expected=41 | predicted=41
# Query-42: expected=42 | predicted=42
# Query-43: expected=43 | predicted=43
# Query-44: expected=44 | predicted=44
# Query-45: expected=45 | predicted=45
# Query-46: expected=46 | predicted=46
# Query-47: expected=47 | predicted=47
# Query-48: expected=48 | predicted=48
# Query-49: expected=49 | predicted=49
# Query-50: expected=50 | predicted=50
# Query-51: expected=51 | predicted=51
# Query-52: expected=52 | predicted=52
# Query-53: expected=53 | predicted=53
# Query-54: expected=54 | predicted=54
# Query-55: expected=55 | predicted=55
# Query-56: expected=56 | predicted=56
# Query-57: expected=57 | predicted=57
# Query-58: expected=58 | predicted=58
# Query-59: expected=59 | predicted=59
# Query-60: expected=60 | predicted=60
# Query-61: expected=61 | predicted=61
# Query-62: expected=62 | predicted=62
# Query-63: expected=63 | predicted=63
# Query-64: expected=64 | predicted=64
# Query-65: expected=65 | predicted=65
# Query-66: expected=66 | predicted=66
# Query-67: expected=67 | predicted=67
# Query-68: expected=68 | predicted=68
# Query-69: expected=69 | predicted=69
# Query-70: expected=70 | predicted=70
# Query-71: expected=71 | predicted=71
# Query-72: expected=72 | predicted=72
# Query-73: expected=73 | predicted=73
# Query-74: expected=74 | predicted=74
# Query-75: expected=75 | predicted=75
# Query-76: expected=76 | predicted=76
# Query-77: expected=77 | predicted=77
# Query-78: expected=78 | predicted=78
# Query-79: expected=79 | predicted=79
# Query-80: expected=80 | predicted=80
# Query-81: expected=81 | predicted=81
# Query-82: expected=82 | predicted=82
# Query-83: expected=83 | predicted=83
# Query-84: expected=84 | predicted=84
# Query-85: expected=85 | predicted=85
# Query-86: expected=86 | predicted=86
# Query-87: expected=87 | predicted=87
# Query-88: expected=88 | predicted=88
# Query-89: expected=89 | predicted=89
# Query-90: expected=90 | predicted=90
# Query-91: expected=91 | predicted=91
# Query-92: expected=92 | predicted=92
# Query-93: expected=93 | predicted=93
# Query-94: expected=94 | predicted=94
# Query-95: expected=95 | predicted=95
# Query-96: expected=96 | predicted=96
# Query-97: expected=97 | predicted=97
# Query-98: expected=98 | predicted=98
# Query-99: expected=99 | predicted=99
# Query-100: expected=100 | predicted=100
#
# 📊 Akurasi manual:
# SVM Benar: 92
# BERT Benar: 100
# Contoh isi test_queries[0]: {'query_id': 1, 'query_text': 'Ini adalah isi dokumen hukum nomor 1. Terdakwa disebut dalam pasal tertentu dan dijatuhi hukuman sesuai peraturan yang berlaku. (Dummy 1)', 'ground_truth': '1'}

# %% [markdown]
# ## Visualisasi & Laporan

# %% [markdown]
# ### Tabel Metrik per Model (TF-IDF + SVM vs. BERT)

# %%
import pandas as pd

# Muat hasil evaluasi dari file CSV
eval_dir = '/content/drive/MyDrive/Penalaran Komputer1/data/eval'
metrics_df = pd.read_csv(f'{eval_dir}/retrieval_metrics.csv')

# Format nilai ke persen
metrics_tabel = metrics_df.copy()
metrics_tabel[['Accuracy', 'Precision', 'Recall', 'F1-Score']] = metrics_tabel[
    ['Accuracy', 'Precision', 'Recall', 'F1-Score']
].applymap(lambda x: f"{x * 100:.2f}%")

# Tampilkan tabel
from IPython.display import display, Markdown

print("📊 Tabel Metrik Evaluasi Per Model:\n")
display(metrics_tabel)
# Out:
# 📊 Tabel Metrik Evaluasi Per Model:
# /tmp/ipython-input-77-1720231534.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ].applymap(lambda x: f"{x * 100:.2f}%")
#             Model Accuracy Precision   Recall F1-Score
# 0    TF-IDF + SVM   92.00%    91.11%   92.00%   91.20%
# 1  BERT Embedding  100.00%   100.00%  100.00%  100.00%

# %% [markdown]
# ### Plot Bar Chart Performance

# %%
import matplotlib.pyplot as plt

# Plot bar chart (ubah ke persen)
metrics_percent = metrics_df.copy()
metrics_percent[['Accuracy', 'Precision', 'Recall', 'F1-Score']] *= 100
metrics_percent.set_index('Model')[['Accuracy', 'Precision', 'Recall', 'F1-Score']].plot(
    kind='bar', figsize=(8, 6), colormap='Set2')

plt.title("Perbandingan Kinerja Model Retrieval")
plt.ylabel("Skor (%)")
plt.ylim(0, 100)
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Diskusi Kasus Gagal Prediksi (Error Analysis)

# %%
# Load file prediksi per query
pred_df = pd.read_csv(f'{eval_dir}/prediction_metrics.csv')

# Tampilkan query yang SALAH diprediksi oleh SVM
print("\n Kasus Gagal – TF-IDF + SVM:")
print(pred_df[pred_df['status_svm'] == "SALAH"][['query_id', 'ground_truth', 'pred_svm']])

# Tampilkan query yang SALAH diprediksi oleh BERT
print("\n Kasus Gagal – BERT Embedding:")
print(pred_df[pred_df['status_bert'] == "SALAH"][['query_id', 'ground_truth', 'pred_bert']])
# Out:
#  Kasus Gagal – TF-IDF + SVM:
#    query_id  ground_truth  pred_svm
# 1         2             2         1
# 2         3             3         1
# 3         4             4         1
# 4         5             5         1
# 5         6             6         1
# 6         7             7         1
# 7         8             8         1
# 8         9             9         1
#
#  Kasus Gagal – BERT Embedding:
# Empty DataFrame
# Columns: [query_id, ground_truth, pred_bert]
# Index: []
